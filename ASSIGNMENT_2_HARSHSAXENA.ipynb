# %% [markdown]
# # **DATA ANALYSIS**

# %% [markdown]
# **Import Basic Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Import .CSV Dataset**

# %%
df_csv = pd.read_csv("employee_data.csv",sep=",")

# %% [markdown]
# **Reading Columns In Dataset**

# %%
df_csv.columns
# Out:
# Index(['age', 'employment_type', 'salary', 'education', 'marital-status',
#        'relationship', 'Gender', 'hours_per_week'],
#       dtype='object')

# %% [markdown]
# **Reading Top Head Values**

# %%
df_csv.head()
# Out:
#    age    employment_type  salary  ...    relationship   Gender hours_per_week
# 0   39          State-gov   77516  ...   Not-in-family     Male             40
# 1   50   Self-emp-not-inc   83311  ...         Husband     Male             13
# 2   38            Private  215646  ...   Not-in-family     Male             40
# 3   53            Private  234721  ...         Husband     Male             40
# 4   28            Private  338409  ...            Wife   Female             40
#
# [5 rows x 8 columns]

# %% [markdown]
# # **ASSINGMENT 2 - DATA ANALYSIS**

# %% [markdown]
# **Problem 1 - Identify Categorical variables & Continuous Variables**

# %% [markdown]
# **Categorical Variables:-**

# %%
df_csv['employment_type'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc'], dtype=object)

# %%
df_csv['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df_csv['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
df_csv['relationship'].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
df_csv['Gender'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %% [markdown]
# **So Total Categorical Variables Are employment_type, education, marital-status, relationship & gender**

# %% [markdown]
# **Continuous Variables:-**

# %%
len(df_csv['age'].unique())
# Out:
# 65

# %%
len(df_csv['salary'].unique())
# Out:
# 966

# %%
len(df_csv['hours_per_week'].unique())
# Out:
# 56

# %% [markdown]
# **So, Total Continuous Variables Are age, salary & hours_per_week**

# %% [markdown]
# **Problem 2 - Carry on a Univariate analysis on all the Variables/Fields. User bar plots for Categorical Variables & histogram or line plot for Continuous ones. Label the plot and axis clearly for intuitive understanding. Mention observations drawn from each Univariate plot**

# %% [markdown]
# **Univariate Analysis On Continuous Variables:-**

# %%
df_csv.hist(figsize=[20,12])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f40840e5898>,
# ...
#       dtype=object)

# %% [markdown]
# **Inferences From Above Graph**
# 1. There are maximum number of employees with age group between 15-45(approx).
# 2. There are some 8-9 employees of 80-85 years & few of them are also touching 90 years itself.
# 2. The maximum hour/week(32-40) work done by only the employees who are greater then 500.
# 3. The salary of majority of employees are ranging from something 0.02 to 0.21 & After that salary goes on decreasing.
# 4. There are some employees who even earn between 0.82 to 1.02.

# %%
df_csv['age'].value_counts().plot.line()

# %%
df_csv['salary'].value_counts().plot.line()

# %%
df_csv['hours_per_week'].value_counts().plot.line()

# %% [markdown]
# **Univariate Analysis On Categorical Variables:-**

# %%
df_csv['employment_type'].value_counts().plot.bar()

# %% [markdown]
# **Inferences From Above Graph**
# 1. There are maximum or whooping number of employees who work(employeed) in private sector
# 2. There are least number of employees working in the federal gov sector

# %%
df_csv['education'].value_counts().plot.bar()

# %% [markdown]
# **Inferences From Above Graph**
# 1. There are maximum number of employees who are having HS-grad qualification
# 2. There are least number of employees who are having Preschool education

# %%
df_csv['marital-status'].value_counts().plot.bar()

# %% [markdown]
# **Inferences From Above Graph**
# 1. There are maximum number of employees who are Married-civ-spouse
# 2. There are least number of employees who are Married-AF-spouse
# 3. There are around 140 employees who are divorced also.
# 4. There are around 30 employees who are widowed too

# %%
df_csv['relationship'].value_counts().plot.bar()

# %% [markdown]
# **Inferences From Above Graph**
# 1. There are around 350+ employees who have husbands
# 2. There are around 125 employees who are unmarried also
# 3. There are around 275 employees who are Not-in-family

# %%
df_csv['Gender'].value_counts().plot.bar()

# %% [markdown]
# **Inferences From Above Graph**
# - There are more number of males in the company(600+) & less number of females in the company(around 340)

# %% [markdown]
# **Problem 3 - Show a bivariate analysis between Salary and hour_per_week.Choose a plot of your choice. Mention the inferences drawn**

# %%
df_csv.plot.scatter(x='salary', y='hours_per_week')

# %%
df_csv.plot.hist(x='salary', y='hours_per_week')

# %% [markdown]
# **Inferences From Above Graph**
# 1. Employees who are working 40 hours per week will earn more salary as compared to the other employees
# 2. In Scatter Plot, There are slightly greater number of employees having salary less than 0.4 units as compared to the employees having salary more than 0.4 units
# 3. In Histogram, There is the maximum salary of 500 earned by employee falls in the group between 32-40 hours/week

# %% [markdown]
# **Problem 4 - For each Education type , showcase the distribution of Salary .Use Seaborn Facetgrid & Line plot.Identify the key observations and mention them**

# %%
fn = sns.FacetGrid(df_csv,col='education',col_wrap=4,height=4,aspect=1)
fn = fn.map(plt.hist,'salary')

# %% [markdown]
# **Inferences From Above Graph**
# 1. The highest salary is earned by the employees who are having the HS-grad qualification(more than 100)
# 2. The second highest number of salary is earned by the employees who are having Some-college degree
# 3. The third highest number of salary is earned by the employees who are having bachelors degree
# 4. There least amount of salary earned by the employees are from the Preschool education qualification
# 5. There are more salary earned by the employees who are just 10th passed as compared to the one's who are 12th passed
# 6. There are also 1 strange fact, which is that the employees having Doctorate degree also not earn more salary infact they are on the least salary category itself

# %% [markdown]
# **Line Plot:-**

# %%
df_csv['salary'].plot.line()

# %% [markdown]
# **Inferences From Above Graph**
# - There is 1 employee having salary greater then 400

# %% [markdown]
# **Problem 5 - Categorizing each Gender & Relationship status (combination of all values) , plot the hours_per_week worked.Choose appropriate plots.Mention the inferences drawn**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fn = sns.FacetGrid(df_csv,col='Gender',row='relationship',palette="GnBu_d",gridspec_kws={"width_ratios": [4, 4]}, height=2.5,aspect=3)
fn = fn.map(plt.hist,"hours_per_week")

# %% [markdown]
# **Inferences From Above Graph**
# 1. There are more number of employees working maximum no. of hours/week when the gender is male & husband too
# 2. There are no work done by the female husbands
# 3. There are also no work done by the employees who are male & wife also
# 4. Male husbands are working more no.of hours/week as compared to Male Not-in-family

# %% [markdown]
# **Problem 6 - How many Males that have Marital status ‘Married-civ-spouse’ are earning above 150,000 ?**

# %%
df_csv.loc[(df_csv['Gender'].isin([' Male'])) & (df_csv['marital-status'].isin([' Married-civ-spouse'])) & (df_csv['salary'] > 150000)][['Gender','marital-status','salary']]
# Out:
#     Gender       marital-status   salary
# 3     Male   Married-civ-spouse   234721
# 7     Male   Married-civ-spouse   209642
# 9     Male   Married-civ-spouse   159449
# 10    Male   Married-civ-spouse   280464
# 15    Male   Married-civ-spouse   245487
# 20    Male   Married-civ-spouse   193524
# 25    Male   Married-civ-spouse   216851
# 27    Male   Married-civ-spouse   180211
# 29    Male   Married-civ-spouse   193366
# 34    Male   Married-civ-spouse   311512
# 39    Male   Married-civ-spouse   265477
# 40    Male   Married-civ-spouse   507875
# 42    Male   Married-civ-spouse   172987
# 45    Male   Married-civ-spouse   337895
# 55    Male   Married-civ-spouse   237993
# 56    Male   Married-civ-spouse   216666
# 59    Male   Married-civ-spouse   188146
# 65    Male   Married-civ-spouse   155537
# 68    Male   Married-civ-spouse   191681
# 72    Male   Married-civ-spouse   162298
# 77    Male   Married-civ-spouse   212759
# 81    Male   Married-civ-spouse   276515
# ...

# %%
len(df_csv.loc[(df_csv['Gender'].isin([' Male'])) & (df_csv['marital-status'].isin([' Married-civ-spouse'])) & (df_csv['salary'] > 150000)][['Gender','marital-status','salary']])
# Out:
# 226

# %% [markdown]
# **So, There are 226 Males that have Marital status ‘Married-civ-spouse’ & earning above 150,000**

# %% [markdown]
# **Problem 7 - Are Divorced Individuals of higher age compared to Individuals that are Not-in-family ? Using mean as a measure , answer the above question & mention the respective age of the two groups**

# %%
x = df_csv[(df_csv['marital-status'] ==' Divorced') & (df_csv['relationship'].isin([' Unmarried' , 'Own-child' , 'Other-relative']))]
x
# Out:
#      age    employment_type  salary  ... relationship   Gender hours_per_week
# 19    43   Self-emp-not-inc  292175  ...    Unmarried   Female             45
# 24    59            Private  109015  ...    Unmarried   Female             40
# 47    44            Private  128354  ...    Unmarried   Female             40
# 91    37            Private  286730  ...    Unmarried   Female             40
# 92    28            Private  212563  ...    Unmarried   Female             25
# 98    48            Private  171095  ...    Unmarried   Female             40
# 150   47          Local-gov  186009  ...    Unmarried   Female             38
# 162   44       Self-emp-inc   78374  ...    Unmarried   Female             40
# 165   36            Private  207157  ...    Unmarried   Female             40
# 204   37          State-gov   48211  ...    Unmarried   Female             35
# 231   41            Private  130408  ...    Unmarried   Female             38
# ...

# %%
x.age.mean()
# Out:
# 40.52173913043478

# %%
y = df_csv[(df_csv['relationship'] ==' Not-in-family') & (df_csv['marital-status'].isin([' Never-married' , 'Separated' , ' Widowed']))]
y
# Out:
#      age    employment_type  salary  ...    relationship   Gender hours_per_week
# 0     39          State-gov   77516  ...   Not-in-family     Male             40
# 8     31            Private   45781  ...   Not-in-family   Female             50
# 13    32            Private  205019  ...   Not-in-family     Male             50
# 30    23          Local-gov  190709  ...   Not-in-family     Male             52
# 44    25            Private  289980  ...   Not-in-family     Male             35
# 49    29            Private  271466  ...   Not-in-family     Male             43
# 73    23            Private  211678  ...   Not-in-family     Male             40
# 80    18            Private  446839  ...   Not-in-family     Male             30
# 88    30            Private   54334  ...   Not-in-family     Male             40
# 89    43        Federal-gov  410867  ...   Not-in-family   Female             50
# 95    29          Local-gov  115585  ...   Not-in-family     Male             50
# ...

# %%
y.age.mean()
# Out:
# 35.20338983050848

# %% [markdown]
# **So, Yes There Are Divorced Individuals of higher age as compared to Individuals that are Not-in-family**

# %% [markdown]
# **So, Using mean as a measure , The respective age of the two groups Are As:-**
#
# **Divorced Individuals - 40.52173913043478**
#
# **Not-in-family Individuals - 35.20338983050848**
