# %% [markdown]
# #This assignement 2 is submitted by Yash Satwani

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df_emp = pd.read_csv('employee_data.csv',sep="\t")
pd.set_option('display.max_rows',df_emp.shape[0]+1)
df_emp.head()
# Out:
#    age    employment_type  salary  ...    relationship   Gender hours_per_week
# 0   39          State-gov   77516  ...   Not-in-family     Male             40
# 1   50   Self-emp-not-inc   83311  ...         Husband     Male             13
# 2   38            Private  215646  ...   Not-in-family     Male             40
# 3   53            Private  234721  ...         Husband     Male             40
# 4   28            Private  338409  ...            Wife   Female             40
#
# [5 rows x 8 columns]

# %%
#1.	Identify Categorical variables & Continuous Variables
#categorial
print(df_emp['employment_type'].unique())
print(df_emp['education'].unique())
print(df_emp['marital-status'].unique())
print(df_emp['Gender'].unique())
print(df_emp['relationship'].unique())
#continious
print(len(df_emp['hours_per_week'].unique()))
print(len(df_emp['age'].unique()))
print(len(df_emp['salary'].unique()))
# Out:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc']
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# [' Male' ' Female']
# [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# 56
# 65
# 966

# %%
#2.Carry on a Univariate analysis on all the Variables/Fields. 
#User bar plots for Categorical Variables & histogram or line plot for Continuous ones.
# Label the plot and axis clearly for intuitive understanding. Mention observations drawn from each Univariate plot
f = df_emp['employment_type'].value_counts().plot.bar()
f.set_xlabel('Type of Employment')
f.set_ylabel('Count of Employee')
# Out:
# Text(0, 0.5, 'Count of Employee')

# %% [markdown]
# **observation**
# 1. the employee_type  Private is the greates.
# 2. All other types are less than 100

# %%
f2 = df_emp['education'].value_counts().plot.bar()
f2.set_title('Eduaction v/s Count of Employee')
f2.set_ylabel('Count of Employee')
f2.set_xlabel('Qualification')
# Out:
# Text(0.5, 0, 'Qualification')

# %% [markdown]
# Observation
# 1. the employees of HS-grad are gratest in numbers.
# 2. 175 - 225 employees are Bachelor or Some-college
# 3. All other qualified are under 50 in number

# %%
f3 = df_emp['marital-status'].value_counts().plot.bar()
f3.set_title('Marital Status v/s Count of Employee')
f3.set_ylabel('Count of Employee')
f3.set_xlabel('Status')
# Out:
# Text(0.5, 0, 'Status')

# %% [markdown]
# Observations
#
# 1. 350 - 450 employees are Married-civ-spouse or Never-Married
# 2. All other status are under 50 except Divorced

# %%
f4 = df_emp['Gender'].value_counts().plot.bar()
f4.set_title('Gender v/s Count of Employee')
f4.set_ylabel('Count of Employee')
f4.set_xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %% [markdown]
# Observation
# 1. the no of male employees are more than female.
# 2. Female are half of the number of the male.

# %%
f5 = df_emp['relationship'].value_counts().plot.bar()
f5.set_title('Relaitonship v/s Count of Employee')
f5.set_ylabel('Count of Employee')
f5.set_xlabel('Status')
# Out:
# Text(0.5, 0, 'Status')

# %% [markdown]
# Observations
#
# 1. Most of the employees are Husband
# 2. All other relationship are under 150 except , Not-in-family.

# %%
df_emp.hist(figsize=[10,5])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf46cbc50>,
# ...
#       dtype=object)

# %%
#3.	Show a bivariate analysis between Salary and hour_per_week.Choose a plot of your choice. Mention the inferences drawn  
df_emp.plot.scatter(x='salary', y='hours_per_week')

# %% [markdown]
# Observations
#
# 1. Employees having salary below 3,00,000 works more i.e (30 - 50) hours/week
# 2. As the salary increases the no of hous spent in work by employee decreases.

# %%
#4.	For each Education type,showcase the distribution of Salary .Use Seaborn Facetgrid & Line plot.
#Identify the key observations and mention them
f=sns.FacetGrid(df_emp,col='education',height=5,col_wrap=5,aspect=1)
f.map(plt.plot,'salary')

# %% [markdown]
# Observations
# 1. Pre-school has minimum no. of employee
# 2. Company's most of the employment is generated form HS-grad
# 3. Most of the employee in every field has salary below 3,00,000
# 4. A employee of Some-college (Quali.) has Maximum salary of above 10,00,000
# 5. Most of the salarry goes to HS-grad too

# %%
#5.Categorizing each Gender & Relationship status (combination of all values) , plot the hours_per_week worked.Choose appropriate plots.Mention the inferences drawn  
f=sns.FacetGrid(df_emp,col='Gender',row='relationship',height=2,aspect=3)
f.map(plt.hist,'hours_per_week')

# %% [markdown]
# observations
#
# 1. the no of employess working for more than 40 hours per week decreases drastically for both genders.
# 2. relationship = not in family males has more no of employes workin for 40 hrs per week than females.
# 3. rellationship = Other-relative and gen = female has the lowest no. of employee in the firm and no emloyee working for more than 40 hours per week.
# 4. relationship = Own-child work for less hours per week compared with other.
# 5. N0. of employees are maximum when gender is male
# 6. Male husbands are working for more hours per week

# %%
#6.	How many Males that have Marital status ‘Married-civ-spouse’ are earning above 150,000 ?
df_emp[(df_emp['Gender'] == " Male") & (df_emp["marital-status"] ==" Married-civ-spouse") & (df_emp['salary'] > 150000)]['Gender'].count()
# Out:
# 226

# %%
#7.	Are Divorced Individuals of higher age compared to Individuals that are Not-in-family ? 
#Using mean as a measure , answer the above question & mention the respective age of the two groups)
print(df_emp[(df_emp['marital-status'] == ' Divorced') & (df_emp["age"] > df_emp["age"].mean())] is df_emp[ (df_emp['relationship'] != ' Not-in-family')])
print(df_emp[(df_emp['marital-status'] == ' Divorced') & (df_emp["age"] > df_emp["age"].mean())]["age"].mean())
print(df_emp[ (df_emp['relationship'] != ' Not-in-family')]["age"].mean())
# Out:
# False
# 47.506024096385545
# 38.03107344632768
